# %% [markdown]
# Converting suplicate CSV to json

# %%
import pandas as pd
import json

# %%
df = pd.read_csv("data/class_meme_.csv",sep=',')

# %%
df = df.drop(columns=['S.No'])

# %%
df = df.fillna(0)

# %%
duplicate_ground_truth = {}

# %%
def row_to_json(row):
    row_list = row.tolist()
    key = row_list.pop(0).lower()
    row_list = [x.lower() for x in row_list if x!= 0]
    if key not in duplicate_ground_truth.keys():
        duplicate_ground_truth[key]=row_list
    else:
        print("something is wrong")
        print(key)

# %%
# %%capture
df.apply(row_to_json,axis=1)

# %%
with open("data/duplicate_ground_truth.json",'w') as out:
    json.dump(duplicate_ground_truth,out,indent=4)

# %%
len(duplicate_ground_truth.keys())
# Out:
# 370

# %% [markdown]
# Name to number mapping json

# %%
df =  pd.read_csv("data/title_description.csv",sep=',')

# %%
df = df.drop(columns=['title','description'])

# %%
title_to_number_map = {}

# %%
def row_to_map(row):
    key = row['link'].replace('/','').lower()
    value = row['image_name']
    if key not in title_to_number_map.keys():
        title_to_number_map[key] = value
    else:
        print("something is wrong")

# %%
# %%capture
df.apply(row_to_map,axis=1)

# %%
title_to_number_map
# Out:
# {'y-u-no': 0,
#  'willy-wonka': 1,
#  'the-most-interesting-man-in-the-world': 2,
#  'futurama-fry': 3,
#  'success-kid': 4,
#  'one-does-not-simply': 5,
#  'bad-luck-brian': 6,
#  'first-world-problems': 7,
#  'philosoraptor': 8,
#  'grumpy-cat': 9,
#  'winter-is-coming': 10,
#  'forever-alone': 11,
#  'good-guy-greg': 12,
#  'scumbag-steve': 13,
#  'what-if-i-told-you': 14,
#  'conspiracy-keanu': 15,
#  'kermit-the-frog-drinking-tea': 16,
#  'yo-dawg': 17,
#  'all-the-things': 18,
#  'insanity-wolf': 19,
#  'joseph-ducreux': 20,
#  'pedobear': 21,
#  'trollface': 22,
#  'skeptical-3rd-world-kid': 23,
#  'annoying-facebook-girl': 24,
#  'disaster-girl': 25,
#  'socially-awkward-penguin': 26,
#  'prepare-yourself': 27,
#  'slowpoke': 28,
#  'dr-evil-meme': 29,
#  'advice-yoda-gives': 30,
#  'joker-mind-loss': 31,
#  'stoner-stanley': 32,
#  'pleaseguy': 33,
#  'foul-bachelor-frog': 34,
#  'batman-slap-robin': 35,
#  'high-expectations-asian-father': 36,
#  'koala-cant-believe-it': 37,
#  'mr-bean': 38,
#  'chuck-norris': 39,
#  'overly-attached-girlfriend': 40,
#  'butthurt-dweller': 41,
#  'desk-flip-rage-guy': 42,
#  'drunk-baby-1': 43,
#  'whyyy': 44,
#  'business-cat': 45,
#  'correction-guy': 46,
#  'south-park-aand-its-gone': 47,
#  'skeptical-african-child': 48,
#  'so-youre-telling-me': 49,
#  'okay-guy': 50,
#  'san-juan-cholo': 51,
#  'sudden-realization-ralph': 52,
#  'what-if-i-told-you-matrix-morpheus': 53,
#  'kill-yourself-guy': 54,
#  'crying-peter-parker': 55,
#  'imagination': 56,
#  'skeptical-african-kid': 57,
#  'southpark-bad-time-meme': 58,
#  'african-children-dancing': 59,
#  'chemistry-cat': 60,
#  'ancient-alien-guy': 61,
#  'chill-out-lemur': 62,
#  'fat-chinese-kid': 63,
#  'see-nobody-cares': 64,
#  'skeptical-black-kid': 65,
#  'captain-picard': 66,
#  'angry-school-boy': 67,
#  'courage-wolf': 68,
#  'matrix-morpheus': 69,
#  'internet-husband': 70,
#  'that-would-be-great': 71,
#  'so-doge': 72,
#  'successful-black-man': 73,
#  'batman-slappp': 74,
#  'sad-trooper': 75,
#  'provincial-man': 76,
#  'challenge-accepted-2': 77,
#  'advice-dog': 78,
#  'archer': 79,
#  'i-should-buy-a-boat-cat': 80,
#  'not-sure-if-troll': 81,
#  'stoner-dog': 82,
#  'keep-calm-and': 83,
#  'guess-who-': 84,
#  'really-stoned-guy': 85,
#  'sunny-student': 86,
#  'bear-grylls': 87,
#  'ihate': 88,
#  'paranoid-parrot': 89,
#  'socially-awesome-awkward-penguin': 90,
#  'rage-fu': 91,
#  'anxiety-cat': 92,
#  'awkward-seal': 93,
#  'bear-grylls-loneliness': 94,
#  'anti-joke-chicken': 95,
#  'maury-lie-detector': 96,
#  'crying-girl-sad': 97,
#  'really-high-guy': 98,
#  'unpopular-opinion-puffin': 99,
#  'african-kids-dancing': 100,
#  'sparta': 101,
#  'kermit-the-frog': 102,
#  'musically-oblivious-8th-grader': 103,
#  'unlucky-brian-strikes-again': 104,
#  'y-u-so': 105,
#  '1889-10-guy': 106,
#  'and-its-gone': 107,
#  'fat-girl': 108,
#  'evil-toddler-kid2': 109,
#  'spongebob-rainbow': 110,
#  'advice-hitler': 111,
#  '-sudden-clarity-clarence': 112,
#  'american-pride-eagle': 113,
#  'rich-men-laughing': 114,
#  'old-lady': 115,
#  'tough-spongebob': 116,
#  'ash-pedreiro': 117,
#  'yeah-if-you-could-just': 118,
#  'first-day-on-the-internet-kid': 119,
#  'ridiculously-photogenic-metalhead': 120,
#  'bender-blackjack-and-hookers': 121,
#  'oprah-you-get-a': 122,
#  'vengeance-dad': 123,
#  'pawn-stars': 124,
#  'sassy-black-woman': 125,
#  'overly-obsessed-girlfriend': 126,
#  'aand-its-gone': 127,
#  'gangnam-style': 128,
#  'angry-arnold': 129,
#  'hipster-ariel': 130,
#  'grumpy-cat-good': 131,
#  'skeptical-third-world-kid': 132,
#  'minecraft-creeper': 133,
#  'dont-you-squidward': 134,
#  'retail-robin': 135,
#  'why-the-fuck': 136,
#  'obama': 137,
#  'gordo-granudo': 138,
#  'newspaper-cat-realization': 139,
#  'mean-girls': 140,
#  'art-student-owl': 141,
#  'so-i-guess-you-could-say-things-are-getting-pretty-serious': 142,
#  'hipster-kitty': 143,
#  'craig-would-be-so-happy': 144,
#  'buddy-jesus': 145,
#  'i-dont-know-who-you-are': 146,
#  'so-then-i-said': 147,
#  'jealous-girl': 148,
#  'you-dont-say-meme': 149,
#  'dr-evil-quote': 150,
#  'lame-pun-coon': 151,
#  'donald-trump': 152,
#  'yaowonkaxd': 153,
#  'es-bakans': 154,
#  'bill-oreilly-proves-god': 155,
#  'mindenki-nyugodjon-le-a-picsba': 156,
#  'skyrim-stan': 157,
#  'bane': 158,
#  'ptsd-karate-kyle': 159,
#  'trologirl': 160,
#  'look-marge': 161,
#  'aysi': 162,
#  'fuck-that-guy': 163,
#  'overly-manlyman': 164,
#  'look-at-all-the-fucks-i-give': 165,
#  'fps-n00b': 166,
#  'picard-facepalm': 167,
#  'pennywise-the-clown': 168,
#  'racist-dog': 169,
#  'pulp-fiction': 170,
#  'cool-dog': 171,
#  'thats-a-paddlin': 172,
#  'in-soviet-russia': 173,
#  'you-shall-not-pass': 174,
#  'crying-face': 175,
#  'your-country-needs-you': 176,
#  'journalist': 177,
#  'bane-meme': 178,
#  'computer-kid': 179,
#  'obama-laughing': 180,
#  'i-have-no-idea-what-im-doing-dog-with-tie': 181,
#  'blackjack-and-hookers-bender': 182,
#  'omsk-crow': 183,
#  'racist-dawg': 184,
#  'crazy-camel-lol': 185,
#  'mafia-baby': 186,
#  'idiot-nerd-girl': 187,
#  'annoying-gamer-kid': 188,
#  'romneymakescom': 189,
#  'guess-who-you': 190,
#  'evil-raccoon': 191,
#  'you-keep-using-that-word-i-dont-think-it-means-what-you-think-it-means': 192,
#  'uncle-dolan': 193,
#  'technologically-impaired-duck': 194,
#  'flniuydl': 195,
#  'roleplaying-rabbit': 196,
#  'successful-mexican': 197,
#  'office-space-boss': 198,
#  'pepperidge-farm-remembers-fg': 199,
#  'calamardo-me-vale': 200,
#  'professor-oak': 201,
#  'bad-factman': 202,
#  'angry-linus': 203,
#  'ryan-gosling-hey-girl-3': 204,
#  'bender-imho': 205,
#  'stupid-monkey': 206,
#  'unimpressed-queen': 207,
#  'you-mean-to-tell-me-black-kid': 208,
#  'mckayla-maroney-not-impressed': 209,
#  'i-dont-always-guy-meme': 210,
#  'i-will-find-you-meme': 211,
#  'i-double-dare-you': 212,
#  'metal-boy-from-hell': 213,
#  'obama-beer': 214,
#  'god': 215,
#  'confused-bill-cosby': 216,
#  'o-seaqu-pedo-mem': 217,
#  'buddy-the-elf': 218,
#  'minecraft-guy': 219,
#  'so-i-got-that-going-on-for-me-which-is-nice': 220,
#  'dr-evil-and-his-minions': 221,
#  'everywhere': 222,
#  'highdrunk-guy': 223,
#  'liberal-douche-garofalo': 224,
#  'angry-cat-meme': 225,
#  'kd-you-the-real-mvp-f': 226,
#  'x-all-the-y': 227,
#  'mens-wearhouse': 228,
#  'youre-gonna-have-a-bad-time': 229,
#  'socially-awesome-penguin': 230,
#  'kill-yourself-guy-blank': 231,
#  'jealous-potteroman': 232,
#  'nick-cage': 233,
#  'tobey-maguire': 234,
#  'bill-murray-caddyshack': 235,
#  'overly-attached-girl': 236,
#  'douchebag-roommate': 237,
#  'fallout-3': 238,
#  'chronic-illness-cat': 239,
#  'stalin-says': 240,
#  'correction-man': 241,
#  'why-cant-i-hold-all-these': 242,
#  'socially-awkward-to-awesome-penguin': 243,
#  'steve-jobs-says': 244,
#  'the-godfather': 245,
#  'foul-bachelorette-frog': 246,
#  'beavis-and-butthead': 247,
#  'asinine-america': 248,
#  'carl-spackler': 249,
#  'justin-bieber': 250,
#  'black-kid': 251,
#  'you-should-feel-bad': 252,
#  'nerdy-kid-lolz': 253,
#  'batman-bitchslap': 254,
#  'un-dia-con-paoly': 255,
#  'chuck-norris-advice': 256,
#  'aaaand-its-gone': 257,
#  'teacher': 258,
#  'dr-evil-quotation-marks': 259,
#  'spock': 260,
#  'scumbag-god': 261,
#  'pawn-stars-rick': 262,
#  'laughing-girls': 263,
#  'yes-this-is-dog': 264,
#  'dogeeeee': 265,
#  'katt-williams-shocked': 266,
#  'dancing-black-kid': 267,
#  'aboriginal': 268,
#  'anchorman-birthday': 269,
#  'nfl-ref-meeting': 270,
#  'a-mi-no-me': 271,
#  'age-of-empires': 272,
#  'never-have-i-been-so-wrong': 273,
#  'dolan-duck': 274,
#  'funes-20-aos': 275,
#  'not-today-arya': 276,
#  'you-have-no-power-here': 277,
#  'bad-advice-cat': 278,
#  'i-will-find-you-and-kill-you': 279,
#  'i-can-haz': 280,
#  'diagnostic-house': 281,
#  'patrick-stewart-wtf': 282,
#  'angry-black-woman': 283,
#  'if-you-know-what': 284,
#  'evil-plan-kid': 285,
#  'burning-house-girl': 286,
#  'baby-wag': 287,
#  'generic-indian-guy': 288,
#  'storytime-jesus': 289,
#  'science-cat': 290,
#  'you-were-the-chosen-one': 291,
#  'pushing-patrick': 292,
#  'shirtless-ryan-gosling': 293,
#  'buzz-lightyear-meme-fixd': 294,
#  'my-precious-gollum': 295,
#  'oh-mer-gerd': 296,
#  'grumpy-cat-santa-hat': 297,
#  'fat-guy': 298,
#  'blank-black': 299,
#  'dolan-meme': 300,
#  'thespian-peacock': 301,
#  'ye-old-englishman': 302,
#  'y-aqu-pondra-si-tuviera-uno': 303,
#  'grumpy-cat-2': 304,
#  'went-full-retard': 305,
#  'uncle-dolan-pls': 306,
#  'pokemon-logic': 307,
#  'sad-bear': 308,
#  'timmy-turners-dad-if-i-had-one': 309,
#  'depression-dog': 310,
#  'that-escalated-quickly-ron-burgundy': 311,
#  'dogeee': 312,
#  'homer-retard': 313,
#  'say-what-one-more-time': 314,
#  'men-in-black': 315,
#  'el-arte-de-amarte-por-nappa': 316,
#  'nicki-minaj': 317,
#  'serious-kip': 318,
#  'raven-symone': 319,
#  'ryan-gosling-hey': 320,
#  'proyodaadvice': 321,
#  'bane-permission-to-die': 322,
#  'wise-confucius': 323,
#  'lebron-james': 324,
#  'nio-malvado-evil-toddler': 325,
#  'freedom-eagle': 326,
#  'sophisticated-cat': 327,
#  'brace-yourselves': 328,
#  'diabetic-cat': 329,
#  'jesse-pinkman': 330,
#  'simpsons-homer': 331,
#  'truestoryxd': 332,
#  'maddog-the-raid': 333,
#  'spoderman': 334,
#  'brace-yourself-meme': 335,
#  'luke-skywalker-nooooooo': 336,
#  'advice-god': 337,
#  'gordo-nerd': 338,
#  'obese-american': 339,
#  'sgt-foley': 340,
#  'ecstatic-michael-phelps': 341,
#  'horney-samus': 342,
#  'how-tough-are-you': 343,
#  'gladiator': 344,
#  'i-see-dead-people': 345,
#  'stevie-wonder': 346,
#  'it-was-a-good-day': 347,
#  'these-are-not-the-droids-you-were-looking-for': 348,
#  'justin-beiber': 349,
#  'say-what-again': 350,
#  'scary-nympho': 351,
#  'dr-phil': 352,
#  'not-impressed-mckayla': 353,
#  'sir-courage-wolf-esquire': 354,
#  'slender-game': 355,
#  'maury-pv': 356,
#  'what-do-we-say-to-the-god-of-death-': 357,
#  'hilda-de-caballito': 358,
#  'what-if-i-told-you-matri': 359,
#  'duck-dynasty-uncle-si': 360,
#  'praise-the-lord-cat': 361,
#  'sad-stormtrooper': 362,
#  'look-at-all-the-things': 363,
#  'counter-strike': 364,
#  'yaazz': 365,
#  'dumb-blonde': 366,
#  'depressed-minecraft-guy': 367,
#  'bob-ross': 368,
#  'quien-dijo-que-es-malo-es-bkn': 369,
#  'cristianoronaldo': 370,
#  'sith-lord': 371,
#  '90s-problems': 372,
#  'jacksparrow': 373,
#  'sudden-realization-guy': 374,
#  'no-se-quiera-pasar-de-verga-we': 375,
#  'advice-jew': 376,
#  'annoying-gym-newbie': 377,
#  'felix-baumgartner': 378,
#  'xbox-one-aint-nobody-got-time-for-that-shit': 379,
#  'good-guy-gregs-dog': 380,
#  'thatd-be-great-guy': 381,
#  'clingy-girlfriend': 382,
#  'housella-ei-suju': 383,
#  'good-advice-duck': 384,
#  'serj-tankian': 385,
#  'sad-face-guy': 386,
#  'grumpy-cat-5': 387,
#  'fry-squint': 388,
#  'oh-crap': 389,
#  'are-you-serious-face': 390,
#  'frodo': 391,
#  'op-will-surely-deliver-skeleton': 392,
#  'forever-alone-date-myself-fail-life': 393,
#  'advice-skrillex': 394,
#  'ill-just-wait-here': 395,
#  'skyrim-whiterun-guard': 396,
#  'batman-slap-robin-blasphemy': 397,
#  'progressive-guitarist': 398,
#  'good-guy-jesus': 399,
#  'santa-claus-troll-face': 400,
#  'chubby-bubbles-girl': 401,
#  'y-u-no-work': 402,
#  'evil-asian-baby': 403,
#  'jack-nicholson-you-cant-handle-the-truth': 404,
#  'odn': 405,
#  'we-will-rebuild': 406,
#  'stay-classy': 407,
#  'crafty-interpreter': 408,
#  'sparta-kick': 409,
#  'cjhanks': 410,
#  'privilege-denying-dude': 411,
#  'ermahgerd-girl': 412,
#  'call-of-duty-addict': 413,
#  'thug-life-on-a-trike': 414,
#  'noob-kid': 415,
#  'the-count-from-sesame-street': 416,
#  'overly-excited-oprah': 417,
#  'tyler-durden': 418,
#  'woah-watch-out-we-got-a-badass-over-here': 419,
#  'dat-ash': 420,
#  'jay-z-problem': 421,
#  'casos-de-familia': 422,
#  'south-park-wow-guy': 423,
#  'old-russian-advisor': 424,
#  'fuck-yeah-band-buffalo': 425,
#  'ollie-williams': 426,
#  'no-memory-gandalf': 427,
#  'o-seaque-pedo': 428,
#  'english-motherfucker-do-you-speak-it': 429,
#  'birthday-grumpy-cat': 430,
#  'hay-tabla': 431,
#  'obsessed-girlfriend': 432,
#  'ric-flair': 433,
#  'spidermanwhisper': 434,
#  'please-guy': 435,
#  'do-you-even-lift-guy': 436,
#  'pizzeria-los-hijos-de-puta': 437,
#  'yu-no': 438,
#  'captain-picard-so-much-win': 439,
#  'sheltering-suburban-mom': 440,
#  'lawn-chair-blown-over': 441,
#  'darth-sidious-mun': 442,
#  'slender-man': 443,
#  'reagan-white-house-laughing': 444,
#  'overly-manly-man': 445,
#  'cm-punk-apologize': 446,
#  'if-i-had-one-doubled': 447,
#  'bane-cat': 448,
#  'bivaloe': 449,
#  'non-jealous-girl': 450,
#  'budnyawkoi': 451,
#  'remboraiden': 452,
#  'spongebob-imagination': 453,
#  'mugatu': 454,
#  'if-i-had-one-timmys-dad': 455,
#  'fanfic-flamingo': 456,
#  'badvice-derpy': 457,
#  'sims': 458,
#  'gaaay': 459,
#  'annoyed-picard': 460,
#  'south-park-craig': 461,
#  'programmers-son': 462,
#  'borat-meme': 463,
#  'sixth-sense': 464,
#  'ordinary-muslim-man': 465,
#  'nemo-seagulls': 466,
#  'ted-movie': 467,
#  'scared-black-man': 468,
#  'christopher-walken-cowbell': 469,
#  'osama': 470,
#  'su-nivel-de-vegeta': 471,
#  'wheres-waldo': 472,
#  'nokia-3310chuck2': 473,
#  'y-you-no': 474,
#  'one-does-not-simply-harry-s': 475,
#  'kill-yourself-please': 476,
#  'unimpressed-mckayla-maroney-2': 477,
#  'kony-the-pimp': 478,
#  'la-tipa-hueca': 479,
#  'obi-wan-kenobi-you-were-my-brother': 480,
#  'maori-guy': 481,
#  'douchebag-college-freshman': 482,
#  'zjarany-zbyszek': 483,
#  'pedo-pope': 484,
#  'sad-zoidberg': 485,
#  'crazy-villain': 486,
#  'typical-proger': 487,
#  'what-you-talkin-bout-willis': 488,
#  'moralfag-mitch': 489,
#  'whisper-sloth': 490,
#  'overly-accepting-thor': 491,
#  'alf-stewart': 492,
#  'insanity-scene-wolf': 493,
#  'zombie': 494,
#  'alfredo-lim-meme': 495,
#  'neil-degrasse-tyson-reaction': 496,
#  'martin-luther-king-jr': 497,
#  'this-is-spartaaa111': 498,
#  'stereotypical-redneck': 499,
#  'veo-gente-muerta': 500,
#  'scumbag-nerd': 501,
#  'advice-borat': 502,
#  'typical-proger-new': 503,
#  'stahp-guise': 504,
#  'malicious-advice-mallard': 505,
#  'uso-carruso': 506,
#  'julia-gillard': 507,
#  'feminist-cunt': 508,
#  'flip-table-meme': 509}

# %%
with open("data/title_to_number_map.json",'w') as out:
    json.dump(title_to_number_map,out,indent=4)

# %% [markdown]
# Classification data

# %%
len(duplicate_ground_truth.keys())
# Out:
# 370

# %%
def classification_data_list():
    data = []
    error = []
    for key in duplicate_ground_truth.keys():
        try:
            number = title_to_number_map[key]
            with open(f'data/captions/{number}.txt','r') as captions_file:
                captions = captions_file.readlines()
            data.extend([(x,key) for x in captions])
        except:
            error.append(key)
    return data,error

# %%
data,error = classification_data_list()

# %%
classification_data = pd.DataFrame(data,columns=["caption","meme_template"])

# %%
classification_data
# Out:
#                                                   caption  meme_template
# 0       I Want To Use The internet But My Mom is on th...   90s-problems
# 1                      march 1994 justin bieber is born\n   90s-problems
# 2       SPENT 20 BUCKS TAKING MY FRIENDS TO NEW "TITAN...   90s-problems
# 3                      memes haven't been invented yet \n   90s-problems
# 4       i want to play gameboy  but mom made me turn o...   90s-problems
# 5         want to burn new metallica cd napster is down\n   90s-problems
# 6       rented good video game 3 days later, now must ...   90s-problems
# 7       my C+C Music Factory cd won't play because it'...   90s-problems
# 8                      blowing on cartridge didn't work\n   90s-problems
# 9       public bus hit a speed bump my cd player skipp...   90s-problems
# 10      The president gets a bj in The Oval Office ......   90s-problems
# 11      can't tell if video game character is male or ...   90s-problems
# 12      Someone called the house phone got kicked off ...   90s-problems
# 13           Friend paged "911" I'm all out of quarters\n   90s-problems
# 14                                    hanson is popular\n   90s-problems
# 15                    no one else has an e-mail address\n   90s-problems
# 16      my cassette tape player got made fun of by kid...   90s-problems
# 17      just rented a vhs last guy didn't rewind it af...   90s-problems
# 18      I just got windows 98 but i lost my tiberian s...   90s-problems
# 19              cant drive my car Anymore Gas is $1.59!\n   90s-problems
# 20      prank caller keeps calling can't figure out wh...   90s-problems
# 21      no one else knows what the hell an "apple" com...   90s-problems
# 22      Bought tickets to upcoming nIrvana concert Kur...   90s-problems
# 23      heated argument with friend DON'T HAVE ENCYCLO...   90s-problems
# 24      people who didn't grow up in the 90s didn't do...   90s-problems
# 25          Girl I like is single don't play any sports\n   90s-problems
# 26                 Girl Asks for my number forgot a pen\n   90s-problems
# 27                  phone rings I don't know who it is.\n   90s-problems
# 28      spent an hour untangling n64 controller cords ...   90s-problems
# 29      *Nsync is the new bieber i mean, the old bieber\n   90s-problems
# ...                                                   ...            ...
# 183055  Avengers Age of Ultron is rape culture fuck OF...  feminist-cunt
# 183056  demonstrates while showing her boobs dont you ...  feminist-cunt
# 183057  You've never been drafted So you should shut t...  feminist-cunt
# 183058  it matters not if she seduced the man they wer...  feminist-cunt
# 183059  My menstrual blood is pure and glorious it als...  feminist-cunt
# 183060  Talking about only women's issues does not tak...  feminist-cunt
# 183061               men should pay for my rape whistle\n  feminist-cunt
# 183062  Writes article on how to recognize narcissisti...  feminist-cunt
# 183063                   i have a vagina. hear me roar!\n  feminist-cunt
# 183064  stop looking at that girl's butt i don't care ...  feminist-cunt
# 183065            men are stupid and easy to manipulate\n  feminist-cunt
# 183066  i say it is emotional abuse you hurt my feelin...  feminist-cunt
# 183067  i ain't saying be a gold digger but you'll get...  feminist-cunt
# 183068  how can you say jenny raped forest gump he jiz...  feminist-cunt
# 183069  this is what a feminist looks like whenever ma...  feminist-cunt
# 183070  a judge granted Spousal Support to a man? nooo...  feminist-cunt
# 183071  no need to call the cops just because she slap...  feminist-cunt
# 183072  Playboy will no longer feature nude women in i...  feminist-cunt
# 183073  but we weren't exclusive you privileged shitlo...  feminist-cunt
# 183074  quick hit yourself in the face with a shoe bef...  feminist-cunt
# 183075  Girl uses men's washroom that's women's libera...  feminist-cunt
# 183076  Enjoys salty male tears in her 20's. Wonders w...  feminist-cunt
# 183077  Complains about patriarchy raises the price on...  feminist-cunt
# 183078  gender superiority now!!! wait, did i just say...  feminist-cunt
# 183079        men you create it then turn it over to us\n  feminist-cunt
# 183080    get hired then find a reason to sue their ass\n  feminist-cunt
# 183081  men should not hurt a women i'll kick your ass...  feminist-cunt
# 183082  why did the feminist cross the road? to protes...  feminist-cunt
# 183083    equality now as long as it is to my advantage\n  feminist-cunt
# 183084  gender equality now except where i lose my adv...  feminist-cunt
#
# [183085 rows x 2 columns]

# %%
classification_data.to_csv("data/classification_data.csv")
