# %%
import pandas as pd

# %%
title_and_class = pd.read_csv("data/title_description.csv")

# %%
title_and_class = title_and_class.drop(columns=['description','image_name'])

# %%
title_and_class['link']=title_and_class['link'].str.replace('/','').str.lower()
title_and_class['title'] = title_and_class['title'].str.lower()

# %%
title_and_class
# Out:
#                                      title  \
# 0                                   y u no
# 1                              willy wonka
# 2    the most interesting man in the world
# 3                             futurama fry
# 4                              success kid
# 5                      one does not simply
# 6                           bad luck brian
# 7                     first world problems
# 8                            philosoraptor
# 9                              grumpy cat
# 10                        winter is coming
# 11                           forever alone
# 12                           good guy greg
# 13                           scumbag steve
# 14                      what if i told you
# 15                        conspiracy keanu
# 16            kermit the frog drinking tea
# 17                                 yo dawg
# 18                          all the things
# 19                           insanity wolf
# 20                          joseph ducreux
# 21                                pedobear
# 22                               trollface
# 23                 skeptical 3rd world kid
# 24                  annoying facebook girl
# 25                           disaster girl
# 26                socially awkward penguin
# 27                        prepare yourself
# 28                                slowpoke
# 29                            dr evil meme
# ..                                     ...
# 480  obi wan kenobi "you were my brother!"
# 481                              maori guy
# 482             douchebag college freshman
# 483                        zjarany zbyszek
# 484                              pedo pope
# 485                           sad zoidberg
# 486                          crazy villain
# 487                         typical_proger
# 488          what you talkin' bout willis
# 489                         moralfag mitch
# 490                          whisper sloth
# 491                  overly accepting thor
# 492                            alf stewart
# 493                    insanity scene wolf
# 494                                 zombie
# 495                       alfredo lim meme
# 496           neil degrasse tyson reaction
# 497                martin luther king jr.
# 498                 this is spartaaa!!11!1
# 499                  stereotypical redneck
# 500                       veo gente muerta
# 501                           scumbag nerd
# 502                           advice borat
# 503                     typical_proger_new
# 504                            stahp guise
# 505               malicious advice mallard
# 506                            uso carruso
# 507                          julia gillard
# 508                          feminist cunt
# 509                        flip table meme
#
#                                       link
# 0                                   y-u-no
# 1                              willy-wonka
# 2    the-most-interesting-man-in-the-world
# 3                             futurama-fry
# 4                              success-kid
# 5                      one-does-not-simply
# 6                           bad-luck-brian
# 7                     first-world-problems
# 8                            philosoraptor
# 9                               grumpy-cat
# 10                        winter-is-coming
# 11                           forever-alone
# 12                           good-guy-greg
# 13                           scumbag-steve
# 14                      what-if-i-told-you
# 15                        conspiracy-keanu
# 16            kermit-the-frog-drinking-tea
# 17                                 yo-dawg
# 18                          all-the-things
# 19                           insanity-wolf
# 20                          joseph-ducreux
# 21                                pedobear
# 22                               trollface
# 23                 skeptical-3rd-world-kid
# 24                  annoying-facebook-girl
# 25                           disaster-girl
# 26                socially-awkward-penguin
# 27                        prepare-yourself
# 28                                slowpoke
# 29                            dr-evil-meme
# ..                                     ...
# 480     obi-wan-kenobi-you-were-my-brother
# 481                              maori-guy
# 482             douchebag-college-freshman
# 483                        zjarany-zbyszek
# 484                              pedo-pope
# 485                           sad-zoidberg
# 486                          crazy-villain
# 487                         typical-proger
# 488            what-you-talkin-bout-willis
# 489                         moralfag-mitch
# 490                          whisper-sloth
# 491                  overly-accepting-thor
# 492                            alf-stewart
# 493                    insanity-scene-wolf
# 494                                 zombie
# 495                       alfredo-lim-meme
# 496           neil-degrasse-tyson-reaction
# 497                  martin-luther-king-jr
# 498                    this-is-spartaaa111
# 499                  stereotypical-redneck
# 500                       veo-gente-muerta
# 501                           scumbag-nerd
# 502                           advice-borat
# 503                     typical-proger-new
# 504                            stahp-guise
# 505               malicious-advice-mallard
# 506                            uso-carruso
# 507                          julia-gillard
# 508                          feminist-cunt
# 509                        flip-table-meme
#
# [510 rows x 2 columns]
